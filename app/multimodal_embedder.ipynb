# %%
import os
from dotenv import load_dotenv
load_dotenv()
api_key = os.environ["MISTRAL_API_KEY"]

# %%
from unstructured.partition.pdf import partition_pdf
from pathlib import Path
file_path = Path("..") / "docs" / "Manuel de formation - Telescope.pdf"

# Reference: https://docs.unstructured.io/open-source/core-functionality/chunking
elements = partition_pdf(
    filename=file_path,
    infer_table_structure=True,            # extract tables
    strategy="hi_res",                     # mandatory to infer tables
    extract_image_block_types=["Image"],   # Add 'Table' to list to extract image of tables
    # image_output_dir_path=output_path,   # if None, images and tables will be saved in base64

    extract_image_block_to_payload=True,   # if true, will extract base64 for API usage
)

# %%
core_elems = [
    el for el in elements
    if el.category not in ("Header", "Footer", "PageNumber")
]

# %%
from langchain_mistralai.chat_models import ChatMistralAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
text_model = ChatMistralAI(mistral_api_key=api_key,model="mistral-large-latest")
prompt_text = """
You are an assistant tasked with summarizing tables and text.
Give a concise summary of the table or text.
The summary must be in french.
Respond only with the summary, no additionnal comment.
Do not start your message by saying "Here is a summary" or anything like that.
Just give the summary as it is.
Optimize your summary embedding as it will be used for RAG.
Table or text chunk: {element}

"""
prompt = ChatPromptTemplate.from_template(prompt_text)
summarize_chain = {"element": lambda x: x} | prompt | text_model | StrOutputParser()

# %%
def summarize_Table(item, summarize_chain):
    return summarize_chain.invoke({"element": item})

# %%
from mistralai import Mistral

client = Mistral(api_key=api_key) 
image_summaries = []
def summarize_image(b64,prefix,suffix):
    prompt = f""" You are given:
- an inline image (base-64) extracted from a PDF
- the French text immediately before and after the image

Text-before:
{prefix}

Text-after:
{suffix}

Task:
- Write **one paragraph (≤ 150 words, in French)** that describes only what is visible in the image.
- If the image is the logo of "Association Gens de la lune", do not describe it.
- Use the surrounding text only to resolve names, labels or context; do not repeat or paraphrase it.
- Keep the prose concise and optimised for semantic retrieval (RAG).
- Your priority is to describe the image, not to summarize the text.
- Do not mention that you are describing an image, and do not start with phrases like “Cette image montre”.
- Do not include any additional information or context that is not visible in the image.
- If the image is not relevant to the text, do not describe it.
Respond in French.  Output only the paragraph."""
    prompt_template = prompt
    messages = [
        {
            "role": "user",
            "content": [
                {"type": "text", "text": prompt_template},
                {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{b64}"}}
            ]
        }
    ]
    
    # Perform inference
    response = client.chat.complete(
        model="pixtral-large-latest",
        messages=messages,
    )
    # Return the model's output
    return response.choices[0].message.content

# %%
def image_wrapper(text_list,i,max_chars=200,elements_nb=3):
    prefix = " \n".join(text_list[-elements_nb:])
    prefix = prefix[-max_chars:]
    suffix = [ el.text for el in core_elems[i:i+elements_nb] if el.category not in {"Image","Table"} ]
    suffix = " \n".join(suffix)
    if len(suffix) > max_chars:
        suffix = suffix[:max_chars]
    return prefix, suffix

# %%
text = ""
text_list = []
for i, element in enumerate(core_elems):
    if element.category == "Image":
        before_image = text_list[-3:]
        b64 = element.metadata.image_base64
        prefix, suffix = image_wrapper(text_list,i)
        image_summary = summarize_image(b64,prefix,suffix)
        print(image_summary + "\n")
        text+= image_summary + "\n"
    elif element.category == "Table":
        html = element.metadata.text_as_html
        table_summary = summarize_Table(html, summarize_chain)
        print(table_summary + "\n")
        text += table_summary + "\n"
        text_list.append(table_summary)
    else :
        print(element.text + "\n")
        text+= element.text  + "\n"
        text_list.append(element.text)
# Out:
# Un observatoire astronomique se dresse sous un ciel nocturne étoilé, teinté de nuances violettes et roses. Le bâtiment, de forme rectangulaire, possède un dôme blanc caractéristique, probablement abritant un télescope. Les environs sont sombres, avec des silhouettes d'arbres visibles en contrebas, suggérant un emplacement isolé, idéal pour l'observation des étoiles. L'horizon est légèrement illuminé par des teintes orangées, indiquant peut-être un coucher ou un lever de soleil.
#
# Formation télescope OBSERVATOIRE DE LA POINTE DU DIABLE
#
# Gens de la Lune | Formation | 2021
#
# Un logo circulaire présentant un croissant de lune stylisé sur un fond blanc. Le texte « Gens de la Lune » est inscrit en lettres orange à côté. Le croissant de lune est épuré, avec une courbe élégante, symbolisant l'astronomie ou l'observation du ciel. Le design est minimaliste, mettant en avant la simplicité et l'élégance.
#
# Table des matières
#
# Le tableau présente divers aspects de l'instrumentation astronomique, incluant des télescopes historiques comme ceux de Galilée et Newton, des technologies modernes comme le télescope Shmidt-Cassagrain, et des composants électroniques et mécaniques pour l'observation astronomique. Il aborde également des sujets tels que l'équilibrage du télescope, la mise au point, la coupole, et divers dispositifs électroniques comme le boîtier MCMT 32 et le dome tracker. Des aspects pratiques comme l'utilisation de l'instrumentation et la mise en fonction de la coupole sont également mentionnés.
#
# 1 Un peu d’histoire....................................................................................................3
#
# 2 Un peu d’informatique….........................................................................................6
#
# 3
#
# 4 Utilisation de l’instrumentation............................................................................18
#
# 4.2 Mise en fonction de l’électronique..................................................................................19
#
# 1
#
# Observatoire de la Pointe du Diable
#
# Le logo présente un casque de spéléologie sur un fond blanc, accompagné du texte “Gens de la Lune” en rouge. Le casque est représenté de manière simplifiée avec une lampe frontale sur le côté gauche. Le design est minimaliste et met en avant l’équipement emblématique de l’exploration souterraine.
#
# Le tableau décrit les différentes sections d'un manuel d'utilisation pour le logiciel Prism, incluant la fenêtre principale, la configuration de la carte du ciel, le pilotage du télescope, et les procédures d'arrêt des instruments et de fermeture de l'observatoire.
#
# 2
#
# Observatoire de la Pointe du Diable
#
# Le logo présente une représentation stylisée d'une lune avec un visage souriant, accompagnée du texte « Gens de la Lune ». Le design est épuré, avec des lignes simples et un contraste marqué entre les éléments noirs et le fond blanc. Le texte est écrit en orange, ajoutant une touche de couleur à l'ensemble. Le visage de la lune, avec ses yeux fermés et son sourire, dégage une impression de sérénité et de bienveillance.
#
# 1 Un peu d’histoire
#
# 1.1 LA PREMIÈRE UTILISATION D’UNE LUNETTE PAR GALILÉE
#
# Galilée, vêtu de vêtements d'époque, est assis et observe à travers une longue lunette astronomique. Il tient un parchemin enroulé dans sa main gauche. À ses côtés, une table supporte un globe terrestre et quelques instruments scientifiques, traduisant un cadre d'étude et d'observation. L'arrière-plan montre un ciel étoilé et des bâtiments anciens, soulignant le contexte astronomique de son travail.
#
# Figure 1 Galilée et sa lunette
#
# Galilée est un astronome italien du XVII siècle. Il a perfectionné et exploité la lunette astronomique, issue de la longue-vue mise au point par l'opticien hollandais Hans Lippershey en 1608, et permettant de voir les objets éloignés.
#
# Sur plus de 60 lunettes qu’il a construites, seules quelques-unes sont de bonnes qualités. Le 7 janvier 1610, il fait une découverte capitale : il remarque trois petites étoiles à côté de Jupiter. Après quelques nuits d'observation, il découvre qu'il y en a une quatrième et qu'elles accompagnent la planète. Il existe donc des corps qui tournent autour d’autre objet que la Terre. Cette dernière n’est donc plus au centre de l’univers !
#
# 1.2 LE TÉLESCOPE DE NEWTON
#
# L’inconvénient des lunettes est la fabrication de la lentille qui se complexifie avec la taille, notamment son poids. En 1666, pour résoudre ce problème, Newton mis au point un instrument avec un système de miroirs : un premier miroir de forme concave, permet de collecter la lumière provenant de la région du ciel pointée, tandis qu’un second, qui est plat, permet de dévier la lumière hors de l’axe optique de manière perpendiculaire.
#
# L’avantage d’utiliser un miroir est sa facilité de fabrication et l’absence d’aberration chromatique (décomposition de la lumière par la lentille)
#
# Le schéma présente un télescope de type Newton, composé d’un tube cylindrique contenant deux miroirs. Le miroir primaire, situé à l’extrémité gauche, réfléchit la lumière vers un miroir secondaire incliné à 45 degrés, qui dirige la lumière vers le point focal où se trouve l’oculaire. Les rayons lumineux entrent par l’ouverture à droite, traversent le tube, et sont redirigés par les miroirs pour être observés à travers l’oculaire. Les trajets des rayons lumineux sont représentés par des flèches rouges, illustrant leur parcours à travers le télescope.
#
# Figure 2 Télescope de type Newton
#
# 3
#
# Observatoire de la Pointe du Diable
#
# Le logo présente un design minimaliste avec un cercle central entouré d'un croissant de lune partiellement visible. Les mots "Gens de la Lune" sont inscrits en rouge à côté du croissant de lune. Le style est épuré et met en avant l'identité visuelle de l'association par des éléments simples et distinctifs.
#
# 1.3 LE TÉLESCOPE SHMIDT-CASSAGRAIN
#
# Sous une coupole de 3,60lm, l’observatoire abrite un télescope de type Schmidt-Cassegrain.
#
# Le télescope présenté est de type Schmidt-Cassegrain, doté d'un tube cylindrique blanc avec des éléments de support mécanique complexes. Il est monté sur un socle robuste, avec un bras articulé permettant la rotation et l'inclinaison. Le miroir principal est partiellement visible, et le système de mise au point semble être situé sur le côté droit. Le design compact et précis suggère une fabrication soignée, adaptée à l'observation astronomique avancée.
#
# Figure 3 – Ce télescope est fabriqué en France par la société Valméca à Puimichel
#
# - Cassegrain, cela signifie que le miroir principal est percé de telle sorte qu’un miroir secondaire placé sur le même axe optique renvoie le foyer à l’arrière du tube optique.
#
# Le montage Cassegrain illustré comprend un miroir principal concave avec un trou central, permettant à la lumière réfléchie de traverser pour atteindre un miroir secondaire convexe situé sur le même axe optique. Les rayons lumineux, après réflexion sur le miroir secondaire, sont dirigés vers un point focal situé à l'arrière du tube. Des flèches rouges indiquent le trajet des rayons lumineux, mettant en évidence la déviation et la convergence de la lumière à travers les deux miroirs. L'ensemble du système optique est représenté de manière schématique, soulignant la disposition et l'interaction des composants optiques.
#
# Figure 4 - Montage Cassegrain
#
# - Schmidt, cela signifie que le tube par une lame de verre.
#
# Ce montage optique comprend un miroir primaire parabolique situé au fond du tube, qui réfléchit la lumière entrante vers un miroir secondaire hyperbolique. Ce second miroir, positionné sur l'axe optique, redirige les faisceaux lumineux à travers un trou central dans le miroir primaire. La lumière converge ensuite vers un plan focal situé à l'arrière du tube. Des éléments correcteurs, probablement des lames de verre, sont placés à l'entrée du tube pour corriger les aberrations optiques. Le dispositif est symétrique, avec des trajets lumineux bien définis illustrant la focalisation des rayons.
#
# optique est fermé
#
# Figure 5 - Montage Schmidt - Cassegrain
#
# 4
#
# Le logo présente un objet circulaire avec un design minimaliste et moderne, qui semble inclure un croissant de lune stylisé. Le texte "Gens de la Lune" est affiché en couleur orange vif à côté de l'objet circulaire. Le design est simple et épuré, mettant en avant l'association entre l'objet illustré et le nom de l'organisation.
#
# La lame de Schmidt permet l’utilisation d’un miroir sphérique qui est bien plus facile à fabriquer. En effet, un miroir sphérique ne permet pas de bien focaliser la lumière, au contraire d’un miroir parabolique, comme le montre les schémas ci-dessous :
#
# Des rayons lumineux parallèles convergent vers un point focal après avoir été réfléchis par une surface courbe. Les rayons incidents sont représentés par des lignes droites dirigées vers la surface réfléchissante. Une fois atteinte la surface, les rayons sont réfléchis et se croisent en un point commun, illustrant la focalisation de la lumière. Un axe horizontal marqué par un trait pointillé divise la scène, tandis qu'une zone colorée à droite indique la présence de la surface réfléchissante.
#
# Des rayons lumineux parallèles arrivent sur une surface courbe, représentée en vert. Ces rayons convergent vers un point focal situé devant la surface courbe. Cependant, ils ne se croisent pas tous exactement au même point, indiquant une focalisation imparfaite. Une ligne horizontale en pointillés marque l'axe optique, tandis que les rayons réfléchis divergent après le point de convergence.
#
# Des rayons lumineux parallèles, représentés en rouge, convergent vers un point focal après réflexion sur une surface courbe. Cette surface, aux bords vert clair, est incurvée de manière à diriger les rayons vers un point précis situé sur l'axe optique, symbolisé par une ligne pointillée horizontale. Les rayons se croisent tous à ce point focal, démontrant une focalisation précise de la lumière.
#
# Figure 6 - Miroir sphérique
#
# Figure 7 – Miroir parabolique
#
# Figure 8 - Montage de Schmidt
#
# 5
#
# 2 Un peu d’informatique…
#
# 2.1 LE SITE WEB
#
# L’association gère le site web de l’Observatoire de la pointe du diable : https://www.astronomie-pointedudiable.fr/
#
# L’image présente une capture de la Lune avec une nette distinction entre les zones claires et sombres de sa surface. Les cratères sont visiblement marqués, offrant une texture détaillée de sa géologie. Les informations au-dessus de la photographie indiquent une date et une heure précises, suggérant qu’il s’agit d’une observation spécifique réalisée dans le cadre d’un projet nommé « Gens de la Lune ». Les détails de l’image soulignent l’intérêt scientifique et pédagogique porté à l’étude des vibrations lunaires.
#
# Page d’accueil
#
# Il est hébergé par la société OVH.
#
# Le site permet d’avoir une visibilité depuis l’extérieur par :
#
# - La publication d’article
#
# - La visualisation du ciel via une caméra Allsky
#
# - Une page de contact
#
# - Une liste d’évènements passés et à venir
#
# De plus chaque membre possède son propre identifiant pour pouvoir :
#
# - Organiser, participer à un évènement
#
# - Ecrire un article
#
# - Accéder à la documentation interne de l’observatoire
#
# Le logo représente un croissant de lune stylisé, intégré dans un cercle. À côté, le texte "Gens de la Lune" est inscrit en lettres capitales orange. Le design est simple et épuré, mettant en avant une esthétique minimaliste.
#
# 6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 8
#       6 b64 = element.metadata.image_base64
#       7 prefix, suffix = image_wrapper(text_list,i)
# ----> 8 image_summary = summarize_image(b64,prefix,suffix)
#       9 print(image_summary + "\n")
#      10 text+= image_summary + "\n"
#
# Cell In[54], line 38, in summarize_image(b64, prefix, suffix)
#      27 messages = [
#      28     {
#      29         "role": "user",
#    (...)     34     }
#      35 ]
#      37 # Perform inference
# ---> 38 response = client.chat.complete(
#      39     model="pixtral-large-latest",
#      40     messages=messages,
#      41 )
#      42 # Return the model's output
#      43 return response.choices[0].message.content
#
# File /usr/local/lib/python3.11/site-packages/mistralai/chat.py:219, in Chat.complete(self, model, messages, temperature, top_p, max_tokens, stream, stop, random_seed, response_format, tools, tool_choice, presence_penalty, frequency_penalty, n, prediction, parallel_tool_calls, safe_prompt, retries, server_url, timeout_ms, http_headers)
#     216 if isinstance(retries, utils.RetryConfig):
#     217     retry_config = (retries, ["429", "500", "502", "503", "504"])
# --> 219 http_res = self.do_request(
#     220     hook_ctx=HookContext(
#     221         base_url=base_url or "",
#     222         operation_id="chat_completion_v1_chat_completions_post",
#     223         oauth2_scopes=[],
#     224         security_source=get_security_from_env(
#     225             self.sdk_configuration.security, models.Security
#     226         ),
#     227     ),
#     228     request=req,
#     229     error_status_codes=["422", "4XX", "5XX"],
#     230     retry_config=retry_config,
#     231 )
#     233 response_data: Any = None
#     234 if utils.match_response(http_res, "200", "application/json"):
#
# File /usr/local/lib/python3.11/site-packages/mistralai/basesdk.py:277, in BaseSDK.do_request(self, hook_ctx, request, error_status_codes, stream, retry_config)
#     275     http_res = utils.retry(do, utils.Retries(retry_config[0], retry_config[1]))
#     276 else:
# --> 277     http_res = do()
#     279 if not utils.match_status_codes(error_status_codes, http_res.status_code):
#     280     http_res = self.sdk_configuration.get_hooks().after_success(
#     281         AfterSuccessContext(hook_ctx), http_res
#     282     )
#
# File /usr/local/lib/python3.11/site-packages/mistralai/basesdk.py:238, in BaseSDK.do_request.<locals>.do()
#     235     if client is None:
#     236         raise ValueError("client is required")
# --> 238     http_res = client.send(req, stream=stream)
#     239 except Exception as e:
#     240     _, e = self.sdk_configuration.get_hooks().after_error(
#     241         AfterErrorContext(hook_ctx), None, e
#     242     )
#
# File /usr/local/lib/python3.11/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File /usr/local/lib/python3.11/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File /usr/local/lib/python3.11/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File /usr/local/lib/python3.11/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File /usr/local/lib/python3.11/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File /usr/local/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File /usr/local/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File /usr/local/lib/python3.11/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File /usr/local/lib/python3.11/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File /usr/local/lib/python3.11/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File /usr/local/lib/python3.11/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File /usr/local/lib/python3.11/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File /usr/local/lib/python3.11/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File /usr/local/lib/python3.11/ssl.py:1295, in SSLSocket.recv(self, buflen, flags)
#    1291     if flags != 0:
#    1292         raise ValueError(
#    1293             "non-zero flags not allowed in calls to recv() on %s" %
#    1294             self.__class__)
# -> 1295     return self.read(buflen)
#    1296 else:
#    1297     return super().recv(buflen, flags)
#
# File /usr/local/lib/python3.11/ssl.py:1168, in SSLSocket.read(self, len, buffer)
#    1166         return self._sslobj.read(len, buffer)
#    1167     else:
# -> 1168         return self._sslobj.read(len)
#    1169 except SSLError as x:
#    1170     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
