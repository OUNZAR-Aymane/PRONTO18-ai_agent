# %%
# !pip install unstructured[pdf]
# Out:
# Requirement already satisfied: unstructured[pdf] in /usr/local/lib/python3.11/site-packages (0.17.2)
# Requirement already satisfied: chardet in /usr/local/lib/python3.11/site-packages (from unstructured[pdf]) (5.2.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.11/site-packages (from unstructured[pdf]) (1.2.0)
# Requirement already satisfied: python-magic in /usr/local/lib/python3.11/site-packages (from unstructured[pdf]) (0.4.27)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/site-packages (from unstructured[pdf]) (5.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/site-packages (from unstructured[pdf]) (3.9.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/site-packages (from unstructured[pdf]) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/site-packages (from unstructured[pdf]) (4.13.4)
# Requirement already satisfied: emoji in /usr/local/lib/python3.11/site-packages (from unstructured[pdf]) (2.14.1)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.11/site-packages (from unstructured[pdf]) (0.6.7)
# Requirement already satisfied: python-iso639 in /usr/local/lib/python3.11/site-packages (from unstructured[pdf]) (2025.2.18)
# Requirement already satisfied: langdetect in /usr/local/lib/python3.11/site-packages (from unstructured[pdf]) (1.0.9)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/site-packages (from unstructured[pdf]) (2.2.5)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.11/site-packages (from unstructured[pdf]) (3.13.0)
# Requirement already satisfied: backoff in /usr/local/lib/python3.11/site-packages (from unstructured[pdf]) (2.2.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/site-packages (from unstructured[pdf]) (4.13.2)
# Requirement already satisfied: unstructured-client in /usr/local/lib/python3.11/site-packages (from unstructured[pdf]) (0.34.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/site-packages (from unstructured[pdf]) (1.17.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/site-packages (from unstructured[pdf]) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/site-packages (from unstructured[pdf]) (7.0.0)
# Requirement already satisfied: python-oxmsg in /usr/local/lib/python3.11/site-packages (from unstructured[pdf]) (0.0.2)
# Requirement already satisfied: html5lib in /usr/local/lib/python3.11/site-packages (from unstructured[pdf]) (1.1)
# Collecting onnx>=1.17.0 (from unstructured[pdf])
#   Downloading onnx-1.17.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Collecting onnxruntime>=1.19.0 (from unstructured[pdf])
#   Downloading onnxruntime-1.21.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: pdf2image in /usr/local/lib/python3.11/site-packages (from unstructured[pdf]) (1.17.0)
# Collecting pdfminer.six (from unstructured[pdf])
#   Downloading pdfminer_six-20250416-py3-none-any.whl.metadata (4.1 kB)
# Collecting pikepdf (from unstructured[pdf])
#   Downloading pikepdf-9.7.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Collecting pi-heif (from unstructured[pdf])
#   Downloading pi_heif-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.5 kB)
# Requirement already satisfied: pypdf in /usr/local/lib/python3.11/site-packages (from unstructured[pdf]) (5.4.0)
# Collecting google-cloud-vision (from unstructured[pdf])
#   Downloading google_cloud_vision-3.10.1-py3-none-any.whl.metadata (9.5 kB)
# Collecting effdet (from unstructured[pdf])
#   Downloading effdet-0.4.1-py3-none-any.whl.metadata (33 kB)
# Collecting unstructured-inference>=0.8.10 (from unstructured[pdf])
#   Downloading unstructured_inference-0.8.10-py3-none-any.whl.metadata (5.3 kB)
# Collecting unstructured.pytesseract>=0.3.12 (from unstructured[pdf])
#   Downloading unstructured.pytesseract-0.3.15-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.11/site-packages (from onnx>=1.17.0->unstructured[pdf]) (5.29.4)
# Collecting coloredlogs (from onnxruntime>=1.19.0->unstructured[pdf])
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.19.0->unstructured[pdf])
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/site-packages (from onnxruntime>=1.19.0->unstructured[pdf]) (24.2)
# Collecting sympy (from onnxruntime>=1.19.0->unstructured[pdf])
#   Downloading sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting python-multipart (from unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.11/site-packages (from unstructured-inference>=0.8.10->unstructured[pdf]) (0.30.2)
# Collecting opencv-python!=4.7.0.68 (from unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting matplotlib (from unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading matplotlib-3.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting torch (from unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading torch-2.7.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting timm (from unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading timm-1.0.15-py3-none-any.whl.metadata (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 2.1 MB/s eta 0:00:00
# Collecting transformers>=4.25.1 (from unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading transformers-4.51.3-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/site-packages (from unstructured-inference>=0.8.10->unstructured[pdf]) (2.2.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/site-packages (from unstructured-inference>=0.8.10->unstructured[pdf]) (1.15.2)
# Collecting pypdfium2 (from unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading pypdfium2-4.30.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.11/site-packages (from unstructured.pytesseract>=0.3.12->unstructured[pdf]) (11.2.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/site-packages (from beautifulsoup4->unstructured[pdf]) (2.7)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/site-packages (from dataclasses-json->unstructured[pdf]) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.11/site-packages (from dataclasses-json->unstructured[pdf]) (0.9.0)
# Collecting torchvision (from effdet->unstructured[pdf])
#   Downloading torchvision-0.22.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Collecting pycocotools>=2.0.2 (from effdet->unstructured[pdf])
#   Downloading pycocotools-2.0.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Collecting omegaconf>=2.0 (from effdet->unstructured[pdf])
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[pdf])
#   Downloading google_api_core-2.24.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 (from google-cloud-vision->unstructured[pdf])
#   Downloading google_auth-2.39.0-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-cloud-vision->unstructured[pdf])
#   Downloading proto_plus-1.26.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.11/site-packages (from html5lib->unstructured[pdf]) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/site-packages (from html5lib->unstructured[pdf]) (0.5.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/site-packages (from nltk->unstructured[pdf]) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/site-packages (from nltk->unstructured[pdf]) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/site-packages (from nltk->unstructured[pdf]) (2024.11.6)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.11/site-packages (from pdfminer.six->unstructured[pdf]) (3.4.1)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.11/site-packages (from pdfminer.six->unstructured[pdf]) (44.0.2)
# Collecting Deprecated (from pikepdf->unstructured[pdf])
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: olefile in /usr/local/lib/python3.11/site-packages (from python-oxmsg->unstructured[pdf]) (0.47)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests->unstructured[pdf]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/site-packages (from requests->unstructured[pdf]) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests->unstructured[pdf]) (2025.4.26)
# Requirement already satisfied: aiofiles>=24.1.0 in /usr/local/lib/python3.11/site-packages (from unstructured-client->unstructured[pdf]) (24.1.0)
# Requirement already satisfied: eval-type-backport>=0.2.0 in /usr/local/lib/python3.11/site-packages (from unstructured-client->unstructured[pdf]) (0.2.2)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.11/site-packages (from unstructured-client->unstructured[pdf]) (0.28.1)
# Requirement already satisfied: nest-asyncio>=1.6.0 in /usr/local/lib/python3.11/site-packages (from unstructured-client->unstructured[pdf]) (1.6.0)
# Requirement already satisfied: pydantic>=2.11.2 in /usr/local/lib/python3.11/site-packages (from unstructured-client->unstructured[pdf]) (2.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.11/site-packages (from unstructured-client->unstructured[pdf]) (1.0.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/site-packages (from unstructured-client->unstructured[pdf]) (0.4.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/site-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[pdf]) (1.17.1)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[pdf])
#   Downloading googleapis_common_protos-1.70.0-py3-none-any.whl.metadata (9.3 kB)
# Collecting grpcio<2.0dev,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[pdf])
#   Downloading grpcio-1.71.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting grpcio-status<2.0.dev0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[pdf])
#   Downloading grpcio_status-1.71.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[pdf]) (5.5.2)
# Collecting pyasn1-modules>=0.2.1 (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[pdf])
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[pdf])
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/site-packages (from httpx>=0.27.0->unstructured-client->unstructured[pdf]) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/site-packages (from httpx>=0.27.0->unstructured-client->unstructured[pdf]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.27.0->unstructured-client->unstructured[pdf]) (0.16.0)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf>=2.0->effdet->unstructured[pdf])
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 1.8 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.11/site-packages (from omegaconf>=2.0->effdet->unstructured[pdf]) (6.0.2)
# Collecting contourpy>=1.0.1 (from matplotlib->unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading contourpy-1.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib->unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading fonttools-4.57.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.5/102.5 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Collecting kiwisolver>=1.3.1 (from matplotlib->unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading kiwisolver-1.4.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/site-packages (from matplotlib->unstructured-inference>=0.8.10->unstructured[pdf]) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/site-packages (from matplotlib->unstructured-inference>=0.8.10->unstructured[pdf]) (2.9.0.post0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/site-packages (from pydantic>=2.11.2->unstructured-client->unstructured[pdf]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/site-packages (from pydantic>=2.11.2->unstructured-client->unstructured[pdf]) (2.33.1)
# Collecting safetensors (from timm->unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/site-packages (from torch->unstructured-inference>=0.8.10->unstructured[pdf]) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/site-packages (from torch->unstructured-inference>=0.8.10->unstructured[pdf]) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/site-packages (from torch->unstructured-inference>=0.8.10->unstructured[pdf]) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/site-packages (from torch->unstructured-inference>=0.8.10->unstructured[pdf]) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch->unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch->unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch->unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch->unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch->unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch->unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch->unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch->unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch->unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch->unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch->unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch->unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch->unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch->unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.3.0 (from torch->unstructured-inference>=0.8.10->unstructured[pdf])
#   Downloading triton-3.3.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.11/site-packages (from triton==3.3.0->torch->unstructured-inference>=0.8.10->unstructured[pdf]) (65.5.1)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->onnxruntime>=1.19.0->unstructured[pdf])
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/site-packages (from transformers>=4.25.1->unstructured-inference>=0.8.10->unstructured[pdf]) (0.21.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured[pdf]) (1.1.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.19.0->unstructured[pdf])
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/site-packages (from pandas->unstructured-inference>=0.8.10->unstructured[pdf]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/site-packages (from pandas->unstructured-inference>=0.8.10->unstructured[pdf]) (2025.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->unstructured[pdf]) (2.22)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[pdf])
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/site-packages (from anyio->httpx>=0.27.0->unstructured-client->unstructured[pdf]) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/site-packages (from jinja2->torch->unstructured-inference>=0.8.10->unstructured[pdf]) (3.0.2)
# Downloading onnx-1.17.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 2.8 MB/s eta 0:00:0000:0100:01m
# Downloading onnxruntime-1.21.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 1.9 MB/s eta 0:00:0000:0100:01
# Downloading unstructured_inference-0.8.10-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 7.8 MB/s eta 0:00:00
# Downloading unstructured.pytesseract-0.3.15-py3-none-any.whl (14 kB)
# Downloading effdet-0.4.1-py3-none-any.whl (112 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.5/112.5 kB 4.1 MB/s eta 0:00:00
# Downloading google_cloud_vision-3.10.1-py3-none-any.whl (526 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.1/526.1 kB 3.4 MB/s eta 0:00:00a 0:00:01
# Downloading pdfminer_six-20250416-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 1.3 MB/s eta 0:00:0000:0100:01
# Downloading pi_heif-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 1.3 MB/s eta 0:00:00a 0:00:01
# Downloading pikepdf-9.7.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 2.4 MB/s eta 0:00:0000:0100:01
# Downloading google_api_core-2.24.2-py3-none-any.whl (160 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.1/160.1 kB 2.8 MB/s eta 0:00:00a 0:00:01
# Downloading google_auth-2.39.0-py2.py3-none-any.whl (212 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.3/212.3 kB 3.5 MB/s eta 0:00:00a 0:00:01
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 3.3 MB/s eta 0:00:00
# Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (63.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 761.5 kB/s eta 0:00:0000:0100:03
# Downloading proto_plus-1.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.9 MB/s eta 0:00:00
# Downloading pycocotools-2.0.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (458 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 458.7/458.7 kB 1.2 MB/s eta 0:00:00a 0:00:01
# Downloading matplotlib-3.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 3.0 MB/s eta 0:00:0000:0100:01
# Downloading timm-1.0.15-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 2.5 MB/s eta 0:00:00a 0:00:01
# Downloading torch-2.7.0-cp311-cp311-manylinux_2_28_x86_64.whl (865.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.2/865.2 MB 2.8 MB/s eta 0:00:0000:0100:05
# Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 4.2 MB/s eta 0:00:0000:0100:03
# Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 4.1 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 3.5 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 3.6 MB/s eta 0:00:00a 0:00:01
# Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━ 293.9/571.0 MB 385.9 kB/s eta 0:11:58

# %%
import os
from dotenv import load_dotenv
import pytesseract
load_dotenv()
api_key = os.environ["MISTRAL_API_KEY"]

# %%
from unstructured.partition.pdf import partition_pdf

file_path = "docs/Manuel de formation - Telescope.pdf"
# Reference: https://docs.unstructured.io/open-source/core-functionality/chunking
chunks = partition_pdf(
    filename=file_path,
    infer_table_structure=True,            # extract tables
    strategy="hi_res",                     # mandatory to infer tables

    extract_image_block_types=["Image"],   # Add 'Table' to list to extract image of tables
    # image_output_dir_path=output_path,   # if None, images and tables will saved in base64

    extract_image_block_to_payload=True,   # if true, will extract base64 for API usage

    chunking_strategy="by_title",          # or 'basic'
    max_characters=10000,                  # defaults to 500
    combine_text_under_n_chars=2000,       # defaults to 0
    new_after_n_chars=6000,

    # extract_images_in_pdf=True,          # deprecated
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from unstructured.partition.pdf import partition_pdf
#       3 file_path = r"C:\Users\ounza\IMT\Semestre_6\PRONTO\ai-agent\docs\stf-8300_manual_12.pdf"
#       4 # Reference: https://docs.unstructured.io/open-source/core-functionality/chunking
#
# File /usr/local/lib/python3.11/site-packages/unstructured/partition/pdf.py:14
#      12 import numpy as np
#      13 import wrapt
# ---> 14 from pdfminer.layout import LTContainer, LTImage, LTItem, LTTextBox
#      15 from pdfminer.utils import open_filename
#      16 from pi_heif import register_heif_opener
#
# ModuleNotFoundError: No module named 'pdfminer'

# %%
from langchain_mistralai.chat_models import ChatMistralAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
import time

# %%
# separate tables from texts
tables = []
texts = []

for chunk in chunks:
    if "Table" in str(type(chunk)):
        tables.append(chunk)

    if "CompositeElement" in str(type((chunk))):
        texts.append(chunk)

# Get the images from the CompositeElement objects
def get_images_base64(chunks):
    images_b64 = []
    for chunk in chunks:
        if "CompositeElement" in str(type(chunk)):
            chunk_els = chunk.metadata.orig_elements
            for el in chunk_els:
                if "Image" in str(type(el)):
                    images_b64.append(el.metadata.image_base64)
    return images_b64

images = get_images_base64(chunks)

# %%
text_model = ChatMistralAI(mistral_api_key=api_key,model="mistral-large-latest")
prompt_text = """
You are an assistant tasked with summarizing tables and text.
Give a concise summary of the table or text.

Respond only with the summary, no additionnal comment.
Do not start your message by saying "Here is a summary" or anything like that.
Just give the summary as it is.

Table or text chunk: {element}

"""
prompt = ChatPromptTemplate.from_template(prompt_text)
summarize_chain = {"element": lambda x: x} | prompt | text_model | StrOutputParser()

# %%
text_summaries = []
def summarize_element(item, summarize_chain):
    return summarize_chain.invoke({"element": item})

for chunk in texts:
    try:
        summary = summarize_element(chunk, summarize_chain)
        text_summaries.append(summary)
        time.sleep(2)
    except Exception as e:
        print(f"Failed to summarize text chunk: {e}")
        text_summaries.append(None)

# %%
# Summarize tables
tables_html = [table.metadata.text_as_html for table in tables]
table_summaries = []
for html in tables_html:
    try:
        summary = summarize_element(html, summarize_chain)
        table_summaries.append(summary)
        time.sleep(2)
    except Exception as e:
        print(f"Failed to summarize table chunk: {e}")
        table_summaries.append(None)

# %%
from mistralai import Mistral

client = Mistral(api_key=api_key) 
image_summaries = []
for image in images:
    prompt_template = """Describe the image in detail. For context,
                    L'image est extraite de la documentation du matériel utilisé dans l'observatoire astronomique de la Pointe du Diable, géré par l'association Gens de la Lune."""
    messages = [
        {
            "role": "user",
            "content": [
                {"type": "text", "text": prompt_template},
                {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{image}"}}
            ]
        }
    ]
    
    # Perform inference
    response = client.chat.complete(
        model="pixtral-large-latest",
        messages=messages,
        max_tokens=300
    )
    # Return the model's output
    print(response.choices[0].message.content)
    image_summaries.append(response.choices[0].message.content)
    time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       3 client = Mistral(api_key=api_key)
#       4 image_summaries = []
# ----> 5 for image in images:
#       6     prompt_template = """Describe the image in detail. For context,
#       7                     L'image est extraite de la documentation du matériel utilisé dans l'observatoire astronomique de la Pointe du Diable, géré par l'association Gens de la Lune."""
#       8     messages = [
#       9         {
#      10             "role": "user",
#    (...)     15         }
#      16     ]
#
# NameError: name 'images' is not defined
